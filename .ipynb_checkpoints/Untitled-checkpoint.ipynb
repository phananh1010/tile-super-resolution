# %%
#TODO: a model trained on 24x24 to 192x192, check its performance
#write dataset that receive one tile video at 192x192

# %%
import cv2

from matplotlib import pyplot as plt
# %matplotlib inline

img1 = cv2.imread('./data/00018.jpg')
img2 = cv2.imread('./data/00018.jpg')

psnr = cv2.PSNR(img1, img2)
print (psnr)
# Out:
# 361.20199909921956

# %%
img1.shape
# Out:
# (2160, 3840, 3)

# %%
img1[1000:1100,1700:2000, :] = 0
cv2.PSNR(img1, img2)
# Out:
# 34.452477883821835

# %%
plt.imshow(img1)
plt.figure()
plt.imshow(img2)
